# %% [markdown]
# # Exploratory Data Analysis

# %%
# import necessary modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## 1. Dataset
#
# The dataset used is taken from Open Power System Data, a free-of-charge platform with data regarding renewable generation capacity of Germany, in time series format and weather data that persisted during that time duration. It can be found in:
#
# https://open-power-system-data.org/
#
# The dataset is about the renewable energy generation is for a year from 1st January 2016 to 1st January 2017 and another dataset that has the climatic information during the same period of time:
# * Time series has wind and solar production capacity in hourly interval.
# * Weather data with wind speed, radiation, temperature and other measurements in a CSV file.

# %% [markdown]
# ## 1.1. Renewable energy production data

# %% [markdown]
# ### Read the data
#
# First, the csv file contains data from alot of regions in europe so we need to extract our related data by filtering out needed columns which is fetch those columns containing the timestamp (columns with 'utc') and the columns containing German data (columns with 'DE').

# %%
production = pd.read_csv("time_series_60min_singleindex.csv",
                        usecols=(lambda s: s.startswith('utc') | s.startswith('DE')),
                        parse_dates=[0], index_col=0)

# %%
production
# Out:
#                            DE_load_actual_entsoe_transparency  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                                 NaN
# 2015-01-01 00:00:00+00:00                             41151.0
# 2015-01-01 01:00:00+00:00                             40135.0
# 2015-01-01 02:00:00+00:00                             39106.0
# 2015-01-01 03:00:00+00:00                             38765.0
# ...                                                       ...
# 2020-09-30 19:00:00+00:00                             57559.0
# 2020-09-30 20:00:00+00:00                             54108.0
# 2020-09-30 21:00:00+00:00                             49845.0
# 2020-09-30 22:00:00+00:00                             46886.0
# 2020-09-30 23:00:00+00:00                             45461.0
#
#                            DE_load_forecast_entsoe_transparency  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                                   NaN
# 2015-01-01 00:00:00+00:00                               39723.0
# 2015-01-01 01:00:00+00:00                               38813.0
# 2015-01-01 02:00:00+00:00                               38490.0
# 2015-01-01 03:00:00+00:00                               38644.0
# ...                                                         ...
# 2020-09-30 19:00:00+00:00                               56708.0
# 2020-09-30 20:00:00+00:00                               53270.0
# 2020-09-30 21:00:00+00:00                               49239.0
# 2020-09-30 22:00:00+00:00                               46620.0
# 2020-09-30 23:00:00+00:00                               44986.0
#
#                            DE_solar_capacity  DE_solar_generation_actual  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00            37248.0                         NaN
# 2015-01-01 00:00:00+00:00            37248.0                         NaN
# 2015-01-01 01:00:00+00:00            37248.0                         NaN
# 2015-01-01 02:00:00+00:00            37248.0                         NaN
# 2015-01-01 03:00:00+00:00            37248.0                         NaN
# ...                                      ...                         ...
# 2020-09-30 19:00:00+00:00                NaN                         0.0
# 2020-09-30 20:00:00+00:00                NaN                         0.0
# 2020-09-30 21:00:00+00:00                NaN                         0.0
# 2020-09-30 22:00:00+00:00                NaN                         0.0
# 2020-09-30 23:00:00+00:00                NaN                         0.0
#
#                            DE_solar_profile  DE_wind_capacity  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00               NaN           27913.0
# 2015-01-01 00:00:00+00:00               NaN           27913.0
# 2015-01-01 01:00:00+00:00               NaN           27913.0
# 2015-01-01 02:00:00+00:00               NaN           27913.0
# 2015-01-01 03:00:00+00:00               NaN           27913.0
# ...                                     ...               ...
# 2020-09-30 19:00:00+00:00               NaN               NaN
# 2020-09-30 20:00:00+00:00               NaN               NaN
# 2020-09-30 21:00:00+00:00               NaN               NaN
# 2020-09-30 22:00:00+00:00               NaN               NaN
# 2020-09-30 23:00:00+00:00               NaN               NaN
#
#                            DE_wind_generation_actual  DE_wind_profile  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                        NaN              NaN
# 2015-01-01 00:00:00+00:00                     8852.0           0.3171
# 2015-01-01 01:00:00+00:00                     9054.0           0.3244
# 2015-01-01 02:00:00+00:00                     9070.0           0.3249
# 2015-01-01 03:00:00+00:00                     9163.0           0.3283
# ...                                              ...              ...
# 2020-09-30 19:00:00+00:00                    10654.0              NaN
# 2020-09-30 20:00:00+00:00                    11836.0              NaN
# 2020-09-30 21:00:00+00:00                    12168.0              NaN
# 2020-09-30 22:00:00+00:00                    12533.0              NaN
# 2020-09-30 23:00:00+00:00                    12798.0              NaN
#
#                            DE_wind_offshore_capacity  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                      667.0
# 2015-01-01 00:00:00+00:00                      667.0
# 2015-01-01 01:00:00+00:00                      667.0
# 2015-01-01 02:00:00+00:00                      667.0
# 2015-01-01 03:00:00+00:00                      667.0
# ...                                              ...
# 2020-09-30 19:00:00+00:00                        NaN
# 2020-09-30 20:00:00+00:00                        NaN
# 2020-09-30 21:00:00+00:00                        NaN
# 2020-09-30 22:00:00+00:00                        NaN
# 2020-09-30 23:00:00+00:00                        NaN
#
#                            DE_wind_offshore_generation_actual  ...  \
# utc_timestamp                                                  ...
# 2014-12-31 23:00:00+00:00                                 NaN  ...
# 2015-01-01 00:00:00+00:00                               517.0  ...
# 2015-01-01 01:00:00+00:00                               514.0  ...
# 2015-01-01 02:00:00+00:00                               518.0  ...
# 2015-01-01 03:00:00+00:00                               520.0  ...
# ...                                                       ...  ...
# 2020-09-30 19:00:00+00:00                              4754.0  ...
# 2020-09-30 20:00:00+00:00                              5194.0  ...
# 2020-09-30 21:00:00+00:00                              5339.0  ...
# 2020-09-30 22:00:00+00:00                              5399.0  ...
# 2020-09-30 23:00:00+00:00                              5381.0  ...
#
#                            DE_tennet_load_actual_entsoe_transparency  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                                        NaN
# 2015-01-01 00:00:00+00:00                                    13841.0
# 2015-01-01 01:00:00+00:00                                    13267.0
# 2015-01-01 02:00:00+00:00                                    12702.0
# 2015-01-01 03:00:00+00:00                                    12452.0
# ...                                                              ...
# 2020-09-30 19:00:00+00:00                                    17719.0
# 2020-09-30 20:00:00+00:00                                    16984.0
# 2020-09-30 21:00:00+00:00                                    15549.0
# 2020-09-30 22:00:00+00:00                                    14595.0
# 2020-09-30 23:00:00+00:00                                    14241.0
#
#                            DE_tennet_load_forecast_entsoe_transparency  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                                          NaN
# 2015-01-01 00:00:00+00:00                                      13362.0
# 2015-01-01 01:00:00+00:00                                      12858.0
# 2015-01-01 02:00:00+00:00                                      12611.0
# 2015-01-01 03:00:00+00:00                                      12490.0
# ...                                                                ...
# 2020-09-30 19:00:00+00:00                                      17190.0
# 2020-09-30 20:00:00+00:00                                      16446.0
# 2020-09-30 21:00:00+00:00                                      15256.0
# 2020-09-30 22:00:00+00:00                                      14586.0
# 2020-09-30 23:00:00+00:00                                      14062.0
#
#                            DE_tennet_solar_generation_actual  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                                NaN
# 2015-01-01 00:00:00+00:00                                NaN
# 2015-01-01 01:00:00+00:00                                NaN
# 2015-01-01 02:00:00+00:00                                NaN
# 2015-01-01 03:00:00+00:00                                NaN
# ...                                                      ...
# 2020-09-30 19:00:00+00:00                                0.0
# 2020-09-30 20:00:00+00:00                                0.0
# 2020-09-30 21:00:00+00:00                                0.0
# 2020-09-30 22:00:00+00:00                                0.0
# 2020-09-30 23:00:00+00:00                                0.0
#
#                            DE_tennet_wind_generation_actual  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                               NaN
# 2015-01-01 00:00:00+00:00                            3866.0
# 2015-01-01 01:00:00+00:00                            3974.0
# 2015-01-01 02:00:00+00:00                            4194.0
# 2015-01-01 03:00:00+00:00                            4446.0
# ...                                                     ...
# 2020-09-30 19:00:00+00:00                            8186.0
# 2020-09-30 20:00:00+00:00                            8879.0
# 2020-09-30 21:00:00+00:00                            8972.0
# 2020-09-30 22:00:00+00:00                            9049.0
# 2020-09-30 23:00:00+00:00                            9162.0
#
#                            DE_tennet_wind_offshore_generation_actual  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                                        NaN
# 2015-01-01 00:00:00+00:00                                      469.0
# 2015-01-01 01:00:00+00:00                                      466.0
# 2015-01-01 02:00:00+00:00                                      470.0
# 2015-01-01 03:00:00+00:00                                      473.0
# ...                                                              ...
# 2020-09-30 19:00:00+00:00                                     4628.0
# 2020-09-30 20:00:00+00:00                                     5056.0
# 2020-09-30 21:00:00+00:00                                     5165.0
# 2020-09-30 22:00:00+00:00                                     5123.0
# 2020-09-30 23:00:00+00:00                                     5124.0
#
#                            DE_tennet_wind_onshore_generation_actual  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                                       NaN
# 2015-01-01 00:00:00+00:00                                    3398.0
# 2015-01-01 01:00:00+00:00                                    3508.0
# 2015-01-01 02:00:00+00:00                                    3724.0
# 2015-01-01 03:00:00+00:00                                    3973.0
# ...                                                             ...
# 2020-09-30 19:00:00+00:00                                    3558.0
# 2020-09-30 20:00:00+00:00                                    3824.0
# 2020-09-30 21:00:00+00:00                                    3807.0
# 2020-09-30 22:00:00+00:00                                    3925.0
# 2020-09-30 23:00:00+00:00                                    4038.0
#
#                            DE_transnetbw_load_actual_entsoe_transparency  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                                            NaN
# 2015-01-01 00:00:00+00:00                                         5307.0
# 2015-01-01 01:00:00+00:00                                         5087.0
# 2015-01-01 02:00:00+00:00                                         4906.0
# 2015-01-01 03:00:00+00:00                                         4865.0
# ...                                                                  ...
# 2020-09-30 19:00:00+00:00                                         7657.0
# 2020-09-30 20:00:00+00:00                                         7072.0
# 2020-09-30 21:00:00+00:00                                         6465.0
# 2020-09-30 22:00:00+00:00                                         5963.0
# 2020-09-30 23:00:00+00:00                                         5668.0
#
#                            DE_transnetbw_load_forecast_entsoe_transparency  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                                              NaN
# 2015-01-01 00:00:00+00:00                                           4703.0
# 2015-01-01 01:00:00+00:00                                           4562.0
# 2015-01-01 02:00:00+00:00                                           4517.0
# 2015-01-01 03:00:00+00:00                                           4601.0
# ...                                                                    ...
# 2020-09-30 19:00:00+00:00                                           7428.0
# 2020-09-30 20:00:00+00:00                                           6870.0
# 2020-09-30 21:00:00+00:00                                           6388.0
# 2020-09-30 22:00:00+00:00                                           5958.0
# 2020-09-30 23:00:00+00:00                                           5735.0
#
#                            DE_transnetbw_solar_generation_actual  \
# utc_timestamp
# 2014-12-31 23:00:00+00:00                                    NaN
# 2015-01-01 00:00:00+00:00                                    NaN
# 2015-01-01 01:00:00+00:00                                    NaN
# 2015-01-01 02:00:00+00:00                                    NaN
# 2015-01-01 03:00:00+00:00                                    NaN
# ...                                                          ...
# 2020-09-30 19:00:00+00:00                                    NaN
# 2020-09-30 20:00:00+00:00                                    NaN
# 2020-09-30 21:00:00+00:00                                    NaN
# 2020-09-30 22:00:00+00:00                                    NaN
# 2020-09-30 23:00:00+00:00                                    NaN
#
#                            DE_transnetbw_wind_onshore_generation_actual
# utc_timestamp
# 2014-12-31 23:00:00+00:00                                           NaN
# 2015-01-01 00:00:00+00:00                                           5.0
# 2015-01-01 01:00:00+00:00                                           7.0
# 2015-01-01 02:00:00+00:00                                           8.0
# 2015-01-01 03:00:00+00:00                                          11.0
# ...                                                                 ...
# 2020-09-30 19:00:00+00:00                                         164.0
# 2020-09-30 20:00:00+00:00                                         242.0
# 2020-09-30 21:00:00+00:00                                         257.0
# 2020-09-30 22:00:00+00:00                                         304.0
# 2020-09-30 23:00:00+00:00                                         342.0
#
# [50401 rows x 41 columns]

# %% [markdown]
# The data file contains information between 2014 and 2020. We will only be interested in the data for 2016.

# %%
production = production.loc[production.index.year == 2016, :]

# %%
production
# Out:
#                            DE_load_actual_entsoe_transparency  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                             40126.0
# 2016-01-01 01:00:00+00:00                             38429.0
# 2016-01-01 02:00:00+00:00                             37484.0
# 2016-01-01 03:00:00+00:00                             37150.0
# 2016-01-01 04:00:00+00:00                             36388.0
# ...                                                       ...
# 2016-12-31 19:00:00+00:00                             49558.0
# 2016-12-31 20:00:00+00:00                             47558.0
# 2016-12-31 21:00:00+00:00                             47600.0
# 2016-12-31 22:00:00+00:00                             46117.0
# 2016-12-31 23:00:00+00:00                             44802.0
#
#                            DE_load_forecast_entsoe_transparency  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                               38163.0
# 2016-01-01 01:00:00+00:00                               36769.0
# 2016-01-01 02:00:00+00:00                               36452.0
# 2016-01-01 03:00:00+00:00                               36578.0
# 2016-01-01 04:00:00+00:00                               37173.0
# ...                                                         ...
# 2016-12-31 19:00:00+00:00                               45915.0
# 2016-12-31 20:00:00+00:00                               44496.0
# 2016-12-31 21:00:00+00:00                               44702.0
# 2016-12-31 22:00:00+00:00                               41879.0
# 2016-12-31 23:00:00+00:00                               39438.0
#
#                            DE_solar_capacity  DE_solar_generation_actual  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00            38631.0                         0.0
# 2016-01-01 01:00:00+00:00            38631.0                         0.0
# 2016-01-01 02:00:00+00:00            38631.0                         0.0
# 2016-01-01 03:00:00+00:00            38631.0                         0.0
# 2016-01-01 04:00:00+00:00            38631.0                         0.0
# ...                                      ...                         ...
# 2016-12-31 19:00:00+00:00            40085.0                         0.0
# 2016-12-31 20:00:00+00:00            40085.0                         0.0
# 2016-12-31 21:00:00+00:00            40085.0                         0.0
# 2016-12-31 22:00:00+00:00            40085.0                         0.0
# 2016-12-31 23:00:00+00:00            40089.0                         0.0
#
#                            DE_solar_profile  DE_wind_capacity  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00               0.0           32812.0
# 2016-01-01 01:00:00+00:00               0.0           32812.0
# 2016-01-01 02:00:00+00:00               0.0           32812.0
# 2016-01-01 03:00:00+00:00               0.0           32812.0
# 2016-01-01 04:00:00+00:00               0.0           32812.0
# ...                                     ...               ...
# 2016-12-31 19:00:00+00:00               0.0           37145.0
# 2016-12-31 20:00:00+00:00               0.0           37145.0
# 2016-12-31 21:00:00+00:00               0.0           37145.0
# 2016-12-31 22:00:00+00:00               0.0           37145.0
# 2016-12-31 23:00:00+00:00               0.0           37149.0
#
#                            DE_wind_generation_actual  DE_wind_profile  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                     8579.0           0.2614
# 2016-01-01 01:00:00+00:00                     8542.0           0.2603
# 2016-01-01 02:00:00+00:00                     8443.0           0.2573
# 2016-01-01 03:00:00+00:00                     8295.0           0.2528
# 2016-01-01 04:00:00+00:00                     7319.0           0.2231
# ...                                              ...              ...
# 2016-12-31 19:00:00+00:00                    15303.0           0.4120
# 2016-12-31 20:00:00+00:00                    15354.0           0.4134
# 2016-12-31 21:00:00+00:00                    14847.0           0.3997
# 2016-12-31 22:00:00+00:00                    15056.0           0.4053
# 2016-12-31 23:00:00+00:00                    15422.0           0.4151
#
#                            DE_wind_offshore_capacity  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                     2162.0
# 2016-01-01 01:00:00+00:00                     2162.0
# 2016-01-01 02:00:00+00:00                     2162.0
# 2016-01-01 03:00:00+00:00                     2162.0
# 2016-01-01 04:00:00+00:00                     2162.0
# ...                                              ...
# 2016-12-31 19:00:00+00:00                     2587.0
# 2016-12-31 20:00:00+00:00                     2587.0
# 2016-12-31 21:00:00+00:00                     2587.0
# 2016-12-31 22:00:00+00:00                     2587.0
# 2016-12-31 23:00:00+00:00                     2591.0
#
#                            DE_wind_offshore_generation_actual  ...  \
# utc_timestamp                                                  ...
# 2016-01-01 00:00:00+00:00                              2285.0  ...
# 2016-01-01 01:00:00+00:00                              2229.0  ...
# 2016-01-01 02:00:00+00:00                              2011.0  ...
# 2016-01-01 03:00:00+00:00                              1943.0  ...
# 2016-01-01 04:00:00+00:00                              1582.0  ...
# ...                                                       ...  ...
# 2016-12-31 19:00:00+00:00                              3310.0  ...
# 2016-12-31 20:00:00+00:00                              3304.0  ...
# 2016-12-31 21:00:00+00:00                              3306.0  ...
# 2016-12-31 22:00:00+00:00                              3308.0  ...
# 2016-12-31 23:00:00+00:00                              3303.0  ...
#
#                            DE_tennet_load_actual_entsoe_transparency  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                                    13311.0
# 2016-01-01 01:00:00+00:00                                    12598.0
# 2016-01-01 02:00:00+00:00                                    12056.0
# 2016-01-01 03:00:00+00:00                                    11886.0
# 2016-01-01 04:00:00+00:00                                    11825.0
# ...                                                              ...
# 2016-12-31 19:00:00+00:00                                    16301.0
# 2016-12-31 20:00:00+00:00                                    15667.0
# 2016-12-31 21:00:00+00:00                                    15838.0
# 2016-12-31 22:00:00+00:00                                    15403.0
# 2016-12-31 23:00:00+00:00                                    14810.0
#
#                            DE_tennet_load_forecast_entsoe_transparency  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                                      13038.0
# 2016-01-01 01:00:00+00:00                                      12245.0
# 2016-01-01 02:00:00+00:00                                      11980.0
# 2016-01-01 03:00:00+00:00                                      11784.0
# 2016-01-01 04:00:00+00:00                                      11734.0
# ...                                                                ...
# 2016-12-31 19:00:00+00:00                                      16148.0
# 2016-12-31 20:00:00+00:00                                      15458.0
# 2016-12-31 21:00:00+00:00                                      15506.0
# 2016-12-31 22:00:00+00:00                                      14464.0
# 2016-12-31 23:00:00+00:00                                      12014.0
#
#                            DE_tennet_solar_generation_actual  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                                0.0
# 2016-01-01 01:00:00+00:00                                0.0
# 2016-01-01 02:00:00+00:00                                0.0
# 2016-01-01 03:00:00+00:00                                0.0
# 2016-01-01 04:00:00+00:00                                0.0
# ...                                                      ...
# 2016-12-31 19:00:00+00:00                                0.0
# 2016-12-31 20:00:00+00:00                                0.0
# 2016-12-31 21:00:00+00:00                                0.0
# 2016-12-31 22:00:00+00:00                                0.0
# 2016-12-31 23:00:00+00:00                                0.0
#
#                            DE_tennet_wind_generation_actual  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                            5615.0
# 2016-01-01 01:00:00+00:00                            5497.0
# 2016-01-01 02:00:00+00:00                            5439.0
# 2016-01-01 03:00:00+00:00                            5451.0
# 2016-01-01 04:00:00+00:00                            4904.0
# ...                                                     ...
# 2016-12-31 19:00:00+00:00                            9253.0
# 2016-12-31 20:00:00+00:00                            9152.0
# 2016-12-31 21:00:00+00:00                            8741.0
# 2016-12-31 22:00:00+00:00                            8750.0
# 2016-12-31 23:00:00+00:00                            8792.0
#
#                            DE_tennet_wind_offshore_generation_actual  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                                     2262.0
# 2016-01-01 01:00:00+00:00                                     2218.0
# 2016-01-01 02:00:00+00:00                                     2005.0
# 2016-01-01 03:00:00+00:00                                     1930.0
# 2016-01-01 04:00:00+00:00                                     1580.0
# ...                                                              ...
# 2016-12-31 19:00:00+00:00                                     2979.0
# 2016-12-31 20:00:00+00:00                                     2972.0
# 2016-12-31 21:00:00+00:00                                     2975.0
# 2016-12-31 22:00:00+00:00                                     2976.0
# 2016-12-31 23:00:00+00:00                                     2971.0
#
#                            DE_tennet_wind_onshore_generation_actual  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                                    3352.0
# 2016-01-01 01:00:00+00:00                                    3279.0
# 2016-01-01 02:00:00+00:00                                    3434.0
# 2016-01-01 03:00:00+00:00                                    3521.0
# 2016-01-01 04:00:00+00:00                                    3324.0
# ...                                                             ...
# 2016-12-31 19:00:00+00:00                                    6275.0
# 2016-12-31 20:00:00+00:00                                    6180.0
# 2016-12-31 21:00:00+00:00                                    5766.0
# 2016-12-31 22:00:00+00:00                                    5774.0
# 2016-12-31 23:00:00+00:00                                    5821.0
#
#                            DE_transnetbw_load_actual_entsoe_transparency  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                                         4652.0
# 2016-01-01 01:00:00+00:00                                         4431.0
# 2016-01-01 02:00:00+00:00                                         4325.0
# 2016-01-01 03:00:00+00:00                                         4337.0
# 2016-01-01 04:00:00+00:00                                         4197.0
# ...                                                                  ...
# 2016-12-31 19:00:00+00:00                                         6131.0
# 2016-12-31 20:00:00+00:00                                         5973.0
# 2016-12-31 21:00:00+00:00                                         6208.0
# 2016-12-31 22:00:00+00:00                                         6071.0
# 2016-12-31 23:00:00+00:00                                         5953.0
#
#                            DE_transnetbw_load_forecast_entsoe_transparency  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                                           3892.0
# 2016-01-01 01:00:00+00:00                                           3705.0
# 2016-01-01 02:00:00+00:00                                           3678.0
# 2016-01-01 03:00:00+00:00                                           3803.0
# 2016-01-01 04:00:00+00:00                                           3809.0
# ...                                                                    ...
# 2016-12-31 19:00:00+00:00                                           5451.0
# 2016-12-31 20:00:00+00:00                                           5415.0
# 2016-12-31 21:00:00+00:00                                           5574.0
# 2016-12-31 22:00:00+00:00                                           5312.0
# 2016-12-31 23:00:00+00:00                                           4617.0
#
#                            DE_transnetbw_solar_generation_actual  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                                    0.0
# 2016-01-01 01:00:00+00:00                                    0.0
# 2016-01-01 02:00:00+00:00                                    0.0
# 2016-01-01 03:00:00+00:00                                    0.0
# 2016-01-01 04:00:00+00:00                                    0.0
# ...                                                          ...
# 2016-12-31 19:00:00+00:00                                    0.0
# 2016-12-31 20:00:00+00:00                                    0.0
# 2016-12-31 21:00:00+00:00                                    0.0
# 2016-12-31 22:00:00+00:00                                    0.0
# 2016-12-31 23:00:00+00:00                                    0.0
#
#                            DE_transnetbw_wind_onshore_generation_actual
# utc_timestamp
# 2016-01-01 00:00:00+00:00                                          25.0
# 2016-01-01 01:00:00+00:00                                          24.0
# 2016-01-01 02:00:00+00:00                                          17.0
# 2016-01-01 03:00:00+00:00                                          20.0
# 2016-01-01 04:00:00+00:00                                          10.0
# ...                                                                 ...
# 2016-12-31 19:00:00+00:00                                          25.0
# 2016-12-31 20:00:00+00:00                                          32.0
# 2016-12-31 21:00:00+00:00                                          38.0
# 2016-12-31 22:00:00+00:00                                          55.0
# 2016-12-31 23:00:00+00:00                                          69.0
#
# [8784 rows x 41 columns]

# %%
production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8784 entries, 2016-01-01 00:00:00+00:00 to 2016-12-31 23:00:00+00:00
# Data columns (total 41 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   DE_load_actual_entsoe_transparency               8784 non-null   float64
#  1   DE_load_forecast_entsoe_transparency             8784 non-null   float64
#  2   DE_solar_capacity                                8784 non-null   float64
#  3   DE_solar_generation_actual                       8712 non-null   float64
#  4   DE_solar_profile                                 8712 non-null   float64
#  5   DE_wind_capacity                                 8784 non-null   float64
#  6   DE_wind_generation_actual                        8710 non-null   float64
#  7   DE_wind_profile                                  8710 non-null   float64
#  8   DE_wind_offshore_capacity                        8784 non-null   float64
#  9   DE_wind_offshore_generation_actual               8710 non-null   float64
#  10  DE_wind_offshore_profile                         8710 non-null   float64
#  11  DE_wind_onshore_capacity                         8784 non-null   float64
#  12  DE_wind_onshore_generation_actual                8712 non-null   float64
#  13  DE_wind_onshore_profile                          8712 non-null   float64
#  14  DE_50hertz_load_actual_entsoe_transparency       8784 non-null   float64
#  15  DE_50hertz_load_forecast_entsoe_transparency     8784 non-null   float64
#  16  DE_50hertz_solar_generation_actual               8784 non-null   float64
#  17  DE_50hertz_wind_generation_actual                8784 non-null   float64
#  18  DE_50hertz_wind_offshore_generation_actual       8784 non-null   float64
#  19  DE_50hertz_wind_onshore_generation_actual        8784 non-null   float64
#  20  DE_LU_load_actual_entsoe_transparency            0 non-null      float64
#  21  DE_LU_load_forecast_entsoe_transparency          0 non-null      float64
#  22  DE_LU_price_day_ahead                            0 non-null      float64
#  23  DE_LU_solar_generation_actual                    0 non-null      float64
#  24  DE_LU_wind_generation_actual                     0 non-null      float64
#  25  DE_LU_wind_offshore_generation_actual            0 non-null      float64
#  26  DE_LU_wind_onshore_generation_actual             0 non-null      float64
#  27  DE_amprion_load_actual_entsoe_transparency       8784 non-null   float64
#  28  DE_amprion_load_forecast_entsoe_transparency     8784 non-null   float64
#  29  DE_amprion_solar_generation_actual               8784 non-null   float64
#  30  DE_amprion_wind_onshore_generation_actual        8784 non-null   float64
#  31  DE_tennet_load_actual_entsoe_transparency        8784 non-null   float64
#  32  DE_tennet_load_forecast_entsoe_transparency      8784 non-null   float64
#  33  DE_tennet_solar_generation_actual                8784 non-null   float64
#  34  DE_tennet_wind_generation_actual                 8784 non-null   float64
#  35  DE_tennet_wind_offshore_generation_actual        8784 non-null   float64
#  36  DE_tennet_wind_onshore_generation_actual         8784 non-null   float64
#  37  DE_transnetbw_load_actual_entsoe_transparency    8784 non-null   float64
#  38  DE_transnetbw_load_forecast_entsoe_transparency  8784 non-null   float64
#  39  DE_transnetbw_solar_generation_actual            8784 non-null   float64
#  40  DE_transnetbw_wind_onshore_generation_actual     8784 non-null   float64
# dtypes: float64(41)
# memory usage: 2.8 MB

# %% [markdown]
# There 8784 entries, which correspond to the number of hours in a leap year like 2016.

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# We are plotting the wind and solar generation capacity against time to get a better idea of the properties of the dataset.

# %%
# create plot
plt.plot(production.index, production['DE_wind_generation_actual'])
plt.title('Actual wind generation in Germany in MW')
plt.xlim(pd.Timestamp('2016-01-01'), pd.Timestamp('2017-01-01'))

# save plot
plt.savefig("wind.png", dpi=200)

# %%
# create plot
plt.plot(production.index, production['DE_solar_generation_actual'], c='OrangeRed')
plt.title('Actual solar generation in Germany in MW')
plt.xlim(pd.Timestamp('2016-01-01'), pd.Timestamp('2017-01-01'))

# save plot
plt.savefig("solar.png", dpi=200)

# %%
production_wind_solar = production[['DE_wind_generation_actual', 'DE_solar_generation_actual']]

# %% [markdown]
# ## 1.2. Weather data

# %% [markdown]
# ### Read the data
#
# Next, we read the weather data for Germany in 2016 by reading the full csv file.
#
# The data in the file contains the following:
#
# * wind
#     - v1: velocity [m/s] @ height h1 (2 meters above displacement height)
#     - v2: velocity [m/s] @ height h2 (10 meters above displacement height)
#     - v_50m: velocity [m/s] @ 50 meters above ground
#     - h1: height above ground [m] (h1 = displacement height +2m)
#     - h2: height above ground [m] (h2 = displacement height +10m)
#     - z0: roughness length [m]
# * solar parameters:
#     - SWTDN: total top-of-the-atmosphere horizontal radiation [W/m²]
#     - SWGDN: total ground horizontal radiation [W/m²]
# * temperature data
#     - T: Temperature [K] @ 2 meters above displacement height (see h1)
# * air data
#     - Rho: air density [kg/m³] @ surface
#     - p: air pressure [Pa] @ surface

# %%
weather = pd.read_csv("data/final_thesis_dataset.csv",
                     parse_dates=[0], index_col=0)

# %%
weather
# Out:
#                            DE_wind_generation_actual  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                     8579.0
# 2016-01-01 01:00:00+00:00                     8542.0
# 2016-01-01 02:00:00+00:00                     8443.0
# 2016-01-01 03:00:00+00:00                     8295.0
# 2016-01-01 04:00:00+00:00                     7319.0
# ...                                              ...
# 2016-12-31 19:00:00+00:00                    15303.0
# 2016-12-31 20:00:00+00:00                    15354.0
# 2016-12-31 21:00:00+00:00                    14847.0
# 2016-12-31 22:00:00+00:00                    15056.0
# 2016-12-31 23:00:00+00:00                    15422.0
#
#                            DE_solar_generation_actual        v1        v2  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                         0.0  2.616758  3.714414
# 2016-01-01 01:00:00+00:00                         0.0  2.564375  3.631055
# 2016-01-01 02:00:00+00:00                         0.0  2.480859  3.516328
# 2016-01-01 03:00:00+00:00                         0.0  2.397148  3.404961
# 2016-01-01 04:00:00+00:00                         0.0  2.305703  3.286602
# ...                                               ...       ...       ...
# 2016-12-31 19:00:00+00:00                         0.0  3.684609  5.233516
# 2016-12-31 20:00:00+00:00                         0.0  3.762305  5.307539
# 2016-12-31 21:00:00+00:00                         0.0  3.792852  5.340195
# 2016-12-31 22:00:00+00:00                         0.0  3.849961  5.420781
# 2016-12-31 23:00:00+00:00                         0.0  3.875156  5.460664
#
#                               v_50m        h1         h2        z0  SWTDN  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00  5.132500  2.546875  10.546875  0.164370    0.0
# 2016-01-01 01:00:00+00:00  4.976094  2.546875  10.546875  0.164331    0.0
# 2016-01-01 02:00:00+00:00  4.794688  2.546875  10.546875  0.164288    0.0
# 2016-01-01 03:00:00+00:00  4.664023  2.546875  10.546875  0.164239    0.0
# 2016-01-01 04:00:00+00:00  4.566289  2.546875  10.546875  0.164199    0.0
# ...                             ...       ...        ...       ...    ...
# 2016-12-31 19:00:00+00:00  7.098086  2.550781  10.550781  0.164608    0.0
# 2016-12-31 20:00:00+00:00  7.083867  2.550781  10.550781  0.164577    0.0
# 2016-12-31 21:00:00+00:00  7.122773  2.546875  10.546875  0.164536    0.0
# 2016-12-31 22:00:00+00:00  7.221172  2.546875  10.546875  0.164504    0.0
# 2016-12-31 23:00:00+00:00  7.283984  2.546875  10.546875  0.164468    0.0
#
#                            SWGDN  ...  humidity  dew  windspeed  winddir  \
# utc_timestamp                     ...
# 2016-01-01 00:00:00+00:00    0.0  ...    100.00  1.9        4.4    180.0
# 2016-01-01 01:00:00+00:00    0.0  ...     93.62  1.9        5.6    196.0
# 2016-01-01 02:00:00+00:00    0.0  ...     94.10  2.0        6.7    230.0
# 2016-01-01 03:00:00+00:00    0.0  ...     94.06  1.1        5.1    218.0
# 2016-01-01 04:00:00+00:00    0.0  ...     93.61  1.0        1.9    202.0
# ...                          ...  ...       ...  ...        ...      ...
# 2016-12-31 19:00:00+00:00    0.0  ...     98.45  1.6       15.0    240.0
# 2016-12-31 20:00:00+00:00    0.0  ...     98.46  1.7       14.2    239.0
# 2016-12-31 21:00:00+00:00    0.0  ...     92.66  1.9       16.6    244.0
# 2016-12-31 22:00:00+00:00    0.0  ...     87.69  2.0       13.2    226.0
# 2016-12-31 23:00:00+00:00    0.0  ...     87.23  1.9       14.8    226.0
#
#                            pressure  visibility  cloudcover        conditions  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00       NaN         0.4        98.4          Overcast
# 2016-01-01 01:00:00+00:00       NaN         0.3        59.2  Partially cloudy
# 2016-01-01 02:00:00+00:00       NaN         1.1        98.4          Overcast
# 2016-01-01 03:00:00+00:00       NaN         1.3        98.4          Overcast
# 2016-01-01 04:00:00+00:00       NaN         2.1        13.8             Clear
# ...                             ...         ...         ...               ...
# 2016-12-31 19:00:00+00:00       NaN         3.9        98.4          Overcast
# 2016-12-31 20:00:00+00:00       NaN         4.3        98.4          Overcast
# 2016-12-31 21:00:00+00:00       NaN         8.0        98.4          Overcast
# 2016-12-31 22:00:00+00:00       NaN        10.0        98.4          Overcast
# 2016-12-31 23:00:00+00:00       NaN        10.0        98.4          Overcast
#
#                            skyType  total_renewable_generation
# utc_timestamp
# 2016-01-01 00:00:00+00:00      1.0                      8579.0
# 2016-01-01 01:00:00+00:00      2.0                      8542.0
# 2016-01-01 02:00:00+00:00      1.0                      8443.0
# 2016-01-01 03:00:00+00:00      1.0                      8295.0
# 2016-01-01 04:00:00+00:00      0.0                      7319.0
# ...                            ...                         ...
# 2016-12-31 19:00:00+00:00      1.0                     15303.0
# 2016-12-31 20:00:00+00:00      1.0                     15354.0
# 2016-12-31 21:00:00+00:00      1.0                     14847.0
# 2016-12-31 22:00:00+00:00      1.0                     15056.0
# 2016-12-31 23:00:00+00:00      1.0                     15422.0
#
# [8711 rows x 24 columns]

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8711 entries, 2016-01-01 00:00:00+00:00 to 2016-12-31 23:00:00+00:00
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DE_wind_generation_actual   8711 non-null   float64
#  1   DE_solar_generation_actual  8711 non-null   float64
#  2   v1                          8711 non-null   float64
#  3   v2                          8711 non-null   float64
#  4   v_50m                       8711 non-null   float64
#  5   h1                          8711 non-null   float64
#  6   h2                          8711 non-null   float64
#  7   z0                          8711 non-null   float64
#  8   SWTDN                       8711 non-null   float64
#  9   SWGDN                       8711 non-null   float64
#  10  T                           8711 non-null   float64
#  11  rho                         8711 non-null   float64
#  12  p                           8711 non-null   float64
#  13  temp                        8710 non-null   float64
#  14  humidity                    8710 non-null   float64
#  15  dew                         8710 non-null   float64
#  16  windspeed                   8710 non-null   float64
#  17  winddir                     8710 non-null   float64
#  18  pressure                    216 non-null    float64
#  19  visibility                  8710 non-null   float64
#  20  cloudcover                  8710 non-null   float64
#  21  conditions                  8710 non-null   object
#  22  skyType                     8710 non-null   float64
#  23  total_renewable_generation  8711 non-null   float64
# dtypes: float64(23), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# Note that the data is given by chuncks of the German geographical territory from 256 different weather station centers so as the renewable energy data is extracted from the overall country we will combine the reading from 256 different stations into single record per hourly timestamp.

# %%
weather.loc[weather.index == '2016-01-01 00:00:00', :]
# Out:
#                            DE_wind_generation_actual  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                     8579.0
#
#                            DE_solar_generation_actual        v1        v2  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                         0.0  2.616758  3.714414
#
#                             v_50m        h1         h2       z0  SWTDN  SWGDN  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00  5.1325  2.546875  10.546875  0.16437    0.0    0.0
#
#                            ...  humidity  dew  windspeed  winddir  pressure  \
# utc_timestamp              ...
# 2016-01-01 00:00:00+00:00  ...     100.0  1.9        4.4    180.0       NaN
#
#                            visibility  cloudcover  conditions  skyType  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00         0.4        98.4    Overcast      1.0
#
#                            total_renewable_generation
# utc_timestamp
# 2016-01-01 00:00:00+00:00                      8579.0
#
# [1 rows x 24 columns]

# %% [markdown]
# Therefore, for any given hour, we have data for 256 'chuncks' of Germany. Dividing the total number of entries by the number of 'chuncks' returns the expected number of hours of a leap year.

# %%
2248704/256
# Out:
# 8784.0

# %% [markdown]
# Averaging over all the 'chuncks':

# %%
weather_by_day = weather.groupby(weather.index).mean(numeric_only=True)

# %%
weather_by_day
# Out:
#                            DE_wind_generation_actual  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                     8579.0
# 2016-01-01 01:00:00+00:00                     8542.0
# 2016-01-01 02:00:00+00:00                     8443.0
# 2016-01-01 03:00:00+00:00                     8295.0
# 2016-01-01 04:00:00+00:00                     7319.0
# ...                                              ...
# 2016-12-31 19:00:00+00:00                    15303.0
# 2016-12-31 20:00:00+00:00                    15354.0
# 2016-12-31 21:00:00+00:00                    14847.0
# 2016-12-31 22:00:00+00:00                    15056.0
# 2016-12-31 23:00:00+00:00                    15422.0
#
#                            DE_solar_generation_actual        v1        v2  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                         0.0  2.616758  3.714414
# 2016-01-01 01:00:00+00:00                         0.0  2.564375  3.631055
# 2016-01-01 02:00:00+00:00                         0.0  2.480859  3.516328
# 2016-01-01 03:00:00+00:00                         0.0  2.397148  3.404961
# 2016-01-01 04:00:00+00:00                         0.0  2.305703  3.286602
# ...                                               ...       ...       ...
# 2016-12-31 19:00:00+00:00                         0.0  3.684609  5.233516
# 2016-12-31 20:00:00+00:00                         0.0  3.762305  5.307539
# 2016-12-31 21:00:00+00:00                         0.0  3.792852  5.340195
# 2016-12-31 22:00:00+00:00                         0.0  3.849961  5.420781
# 2016-12-31 23:00:00+00:00                         0.0  3.875156  5.460664
#
#                               v_50m        h1         h2        z0  SWTDN  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00  5.132500  2.546875  10.546875  0.164370    0.0
# 2016-01-01 01:00:00+00:00  4.976094  2.546875  10.546875  0.164331    0.0
# 2016-01-01 02:00:00+00:00  4.794688  2.546875  10.546875  0.164288    0.0
# 2016-01-01 03:00:00+00:00  4.664023  2.546875  10.546875  0.164239    0.0
# 2016-01-01 04:00:00+00:00  4.566289  2.546875  10.546875  0.164199    0.0
# ...                             ...       ...        ...       ...    ...
# 2016-12-31 19:00:00+00:00  7.098086  2.550781  10.550781  0.164608    0.0
# 2016-12-31 20:00:00+00:00  7.083867  2.550781  10.550781  0.164577    0.0
# 2016-12-31 21:00:00+00:00  7.122773  2.546875  10.546875  0.164536    0.0
# 2016-12-31 22:00:00+00:00  7.221172  2.546875  10.546875  0.164504    0.0
# 2016-12-31 23:00:00+00:00  7.283984  2.546875  10.546875  0.164468    0.0
#
#                            SWGDN  ...  temp  humidity  dew  windspeed  \
# utc_timestamp                     ...
# 2016-01-01 00:00:00+00:00    0.0  ...   1.9    100.00  1.9        4.4
# 2016-01-01 01:00:00+00:00    0.0  ...   2.8     93.62  1.9        5.6
# 2016-01-01 02:00:00+00:00    0.0  ...   2.9     94.10  2.0        6.7
# 2016-01-01 03:00:00+00:00    0.0  ...   2.0     94.06  1.1        5.1
# 2016-01-01 04:00:00+00:00    0.0  ...   1.9     93.61  1.0        1.9
# ...                          ...  ...   ...       ...  ...        ...
# 2016-12-31 19:00:00+00:00    0.0  ...   1.9     98.45  1.6       15.0
# 2016-12-31 20:00:00+00:00    0.0  ...   1.9     98.46  1.7       14.2
# 2016-12-31 21:00:00+00:00    0.0  ...   2.9     92.66  1.9       16.6
# 2016-12-31 22:00:00+00:00    0.0  ...   3.9     87.69  2.0       13.2
# 2016-12-31 23:00:00+00:00    0.0  ...   3.8     87.23  1.9       14.8
#
#                            winddir  pressure  visibility  cloudcover  skyType  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00    180.0       NaN         0.4        98.4      1.0
# 2016-01-01 01:00:00+00:00    196.0       NaN         0.3        59.2      2.0
# 2016-01-01 02:00:00+00:00    230.0       NaN         1.1        98.4      1.0
# 2016-01-01 03:00:00+00:00    218.0       NaN         1.3        98.4      1.0
# 2016-01-01 04:00:00+00:00    202.0       NaN         2.1        13.8      0.0
# ...                            ...       ...         ...         ...      ...
# 2016-12-31 19:00:00+00:00    240.0       NaN         3.9        98.4      1.0
# 2016-12-31 20:00:00+00:00    239.0       NaN         4.3        98.4      1.0
# 2016-12-31 21:00:00+00:00    244.0       NaN         8.0        98.4      1.0
# 2016-12-31 22:00:00+00:00    226.0       NaN        10.0        98.4      1.0
# 2016-12-31 23:00:00+00:00    226.0       NaN        10.0        98.4      1.0
#
#                            total_renewable_generation
# utc_timestamp
# 2016-01-01 00:00:00+00:00                      8579.0
# 2016-01-01 01:00:00+00:00                      8542.0
# 2016-01-01 02:00:00+00:00                      8443.0
# 2016-01-01 03:00:00+00:00                      8295.0
# 2016-01-01 04:00:00+00:00                      7319.0
# ...                                               ...
# 2016-12-31 19:00:00+00:00                     15303.0
# 2016-12-31 20:00:00+00:00                     15354.0
# 2016-12-31 21:00:00+00:00                     14847.0
# 2016-12-31 22:00:00+00:00                     15056.0
# 2016-12-31 23:00:00+00:00                     15422.0
#
# [8710 rows x 23 columns]

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# Plotting weather-related quantities during 2016 to get a better idea of the properties of the dataset.

# %%
# create plot
plt.plot(weather_by_day.index, weather_by_day['v1'])
plt.title('Wind velocity 2 m above displacement height (m/s)')
plt.xlim(pd.Timestamp('2016-01-01'), pd.Timestamp('2017-01-01'))

# save plot
plt.savefig("v1.png", dpi=200)

# %%
# create plot
plt.plot(weather_by_day.index, weather_by_day['v2'])
plt.title('Wind velocity 10 m above displacement height (m/s)')
plt.xlim(pd.Timestamp('2016-01-01'), pd.Timestamp('2017-01-01'))

# save plot
plt.savefig("v2.png", dpi=200)

# %%
# create plot
plt.plot(weather_by_day.index, weather_by_day['v_50m'])
plt.title('Wind velocity 50 m above displacement height (m/s)')
plt.xlim(pd.Timestamp('2016-01-01'), pd.Timestamp('2017-01-01'))

plt.savefig("v_50m.png", dpi=200)

# %%
# create plot
plt.plot(weather_by_day.index, weather_by_day['z0'])
plt.title('Roughness Length')
plt.xlim(pd.Timestamp('2016-01-01'), pd.Timestamp('2017-01-01'))

plt.savefig("z0.png", dpi=200)

# %%
# create plot
plt.plot(weather_by_day.index, weather_by_day['SWGDN'], c='OrangeRed')
plt.title('Ground horizontal radiation (W/m²)')
plt.xlim(pd.Timestamp('2016-01-01'), pd.Timestamp('2017-01-01'))

# save plot
plt.savefig("radiation.png", dpi=200)

# %%
# create plot
plt.plot(weather_by_day.index, weather_by_day['SWTDN'], c='OrangeRed')
plt.title('Atmospheric horizontal radiation (W/m²)')
plt.xlim(pd.Timestamp('2016-01-01'), pd.Timestamp('2017-01-01'))

# save plot
plt.savefig("atomspheric-radiation.png", dpi=200)

# %%
# create plot
plt.plot(weather_by_day.index, weather_by_day['T'], c='OrangeRed')
plt.title('Temperature (K)')
plt.xlim(pd.Timestamp('2016-01-01'), pd.Timestamp('2017-01-01'))

# save plot
plt.savefig("temperature_K.png", dpi=200)

# %% [markdown]
# # 1.3 Weather Forecast Data

# %% [markdown]
# ### Read the data
#
# Next, we read the historical weather forecast data for Germany in 2016 that is obtained from visualcrossing.com, Visual Crossing is a FORECAST & HISTORICAL WEATHER DATA gathering organization that provides a single source for worldwide weather data, weather APIs, and geospatial mapping for businesses and professionals. This is a paid service and they charge 0.0001$ each record.
#
# So in my case I extracted hourly records for a year from 1st January, 2016 to 1st January, 2017. Which is 8784 records and I was charged 0.8784$ = 0.74euros.
#
# The data in the file contains the following:
# * wind
#     - windspeed: 2 minute average of wind speed
#     - winddir: 2 minute average of wind direction
#     - pressure: Sea level Pressure
# * solar
#     - visibility: Distance that can be viewed
#     - cloudcover: Percentage of sky that is covered by cloud
#     - uvindex: UV Index maps the maximum UV level forecast under either clear or cloudy sky.
# * general
#     - temp: Land Surface Temperature calculated (usually 1.5 meters above land)
#     - humidity: Humidity calculated usually at the same height.
#     - dew: Dew Point Temperature
#     - precip: Amount of liquid equivalent precipitation (rain, snow etc.)
#     - weather condition: string column with the below 3 unique values converted to one hot encoding
#         - Clear: If that hour had a clear sky.
#         - Overcast: If that hour had an overcast.
#         - Partially cloudy: If that hour was partially cloudy.

# %%
weather_forecast_data = pd.read_csv('data/final_thesis_dataset.csv', parse_dates=[0])

# %%
weather_forecast_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8711 entries, 0 to 8710
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   utc_timestamp               8711 non-null   datetime64[ns, UTC]
#  1   DE_wind_generation_actual   8711 non-null   float64
#  2   DE_solar_generation_actual  8711 non-null   float64
#  3   v1                          8711 non-null   float64
#  4   v2                          8711 non-null   float64
#  5   v_50m                       8711 non-null   float64
#  6   h1                          8711 non-null   float64
#  7   h2                          8711 non-null   float64
#  8   z0                          8711 non-null   float64
#  9   SWTDN                       8711 non-null   float64
#  10  SWGDN                       8711 non-null   float64
#  11  T                           8711 non-null   float64
#  12  rho                         8711 non-null   float64
#  13  p                           8711 non-null   float64
#  14  temp                        8710 non-null   float64
#  15  humidity                    8710 non-null   float64
#  16  dew                         8710 non-null   float64
#  17  windspeed                   8710 non-null   float64
#  18  winddir                     8710 non-null   float64
#  19  pressure                    216 non-null    float64
#  20  visibility                  8710 non-null   float64
#  21  cloudcover                  8710 non-null   float64
#  22  conditions                  8710 non-null   object
#  23  skyType                     8710 non-null   float64
#  24  total_renewable_generation  8711 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(23), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# ## 2. Merge DataFrames

# %% [markdown]
# As suggested by the above plots from both datasets (and by common sense), there seems to be some correlation between the wind and solar generation and some of the measured weather quantities.
#
# First, let's merge the two DataFrames into a single DataFrame. But few records were dropped after merge as during my execution I noticed that few records of generation capacity were not included due to which they had to be removed as otherwise prediction variable y will be N/A which no algorithm will accept.

# %%
# merge production_wind_solar and weather_by_day DataFrames
thesis_dataset = pd.merge(production_wind_solar, weather_by_day, how='left', left_index=True, right_index=True)
print(thesis_dataset.columns.tolist())
thesis_dataset = thesis_dataset.dropna(subset=['DE_wind_generation_actual_y','DE_solar_generation_actual_y'])
thesis_dataset = thesis_dataset.drop(['cumulated hours', 'lat', 'lon'], axis=1,errors='ignore')
# Out:
# ['DE_wind_generation_actual_x', 'DE_solar_generation_actual_x', 'DE_wind_generation_actual_y', 'DE_solar_generation_actual_y', 'v1', 'v2', 'v_50m', 'h1', 'h2', 'z0', 'SWTDN', 'SWGDN', 'T', 'rho', 'p', 'temp', 'humidity', 'dew', 'windspeed', 'winddir', 'pressure', 'visibility', 'cloudcover', 'skyType', 'total_renewable_generation']

# %%
thesis_dataset
# Out:
#                            DE_wind_generation_actual_x  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                       8579.0
# 2016-01-01 01:00:00+00:00                       8542.0
# 2016-01-01 02:00:00+00:00                       8443.0
# 2016-01-01 03:00:00+00:00                       8295.0
# 2016-01-01 04:00:00+00:00                       7319.0
# ...                                                ...
# 2016-12-31 19:00:00+00:00                      15303.0
# 2016-12-31 20:00:00+00:00                      15354.0
# 2016-12-31 21:00:00+00:00                      14847.0
# 2016-12-31 22:00:00+00:00                      15056.0
# 2016-12-31 23:00:00+00:00                      15422.0
#
#                            DE_solar_generation_actual_x  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                           0.0
# 2016-01-01 01:00:00+00:00                           0.0
# 2016-01-01 02:00:00+00:00                           0.0
# 2016-01-01 03:00:00+00:00                           0.0
# 2016-01-01 04:00:00+00:00                           0.0
# ...                                                 ...
# 2016-12-31 19:00:00+00:00                           0.0
# 2016-12-31 20:00:00+00:00                           0.0
# 2016-12-31 21:00:00+00:00                           0.0
# 2016-12-31 22:00:00+00:00                           0.0
# 2016-12-31 23:00:00+00:00                           0.0
#
#                            DE_wind_generation_actual_y  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                       8579.0
# 2016-01-01 01:00:00+00:00                       8542.0
# 2016-01-01 02:00:00+00:00                       8443.0
# 2016-01-01 03:00:00+00:00                       8295.0
# 2016-01-01 04:00:00+00:00                       7319.0
# ...                                                ...
# 2016-12-31 19:00:00+00:00                      15303.0
# 2016-12-31 20:00:00+00:00                      15354.0
# 2016-12-31 21:00:00+00:00                      14847.0
# 2016-12-31 22:00:00+00:00                      15056.0
# 2016-12-31 23:00:00+00:00                      15422.0
#
#                            DE_solar_generation_actual_y        v1        v2  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                           0.0  2.616758  3.714414
# 2016-01-01 01:00:00+00:00                           0.0  2.564375  3.631055
# 2016-01-01 02:00:00+00:00                           0.0  2.480859  3.516328
# 2016-01-01 03:00:00+00:00                           0.0  2.397148  3.404961
# 2016-01-01 04:00:00+00:00                           0.0  2.305703  3.286602
# ...                                                 ...       ...       ...
# 2016-12-31 19:00:00+00:00                           0.0  3.684609  5.233516
# 2016-12-31 20:00:00+00:00                           0.0  3.762305  5.307539
# 2016-12-31 21:00:00+00:00                           0.0  3.792852  5.340195
# 2016-12-31 22:00:00+00:00                           0.0  3.849961  5.420781
# 2016-12-31 23:00:00+00:00                           0.0  3.875156  5.460664
#
#                               v_50m        h1         h2        z0  ...  temp  \
# utc_timestamp                                                       ...
# 2016-01-01 00:00:00+00:00  5.132500  2.546875  10.546875  0.164370  ...   1.9
# 2016-01-01 01:00:00+00:00  4.976094  2.546875  10.546875  0.164331  ...   2.8
# 2016-01-01 02:00:00+00:00  4.794688  2.546875  10.546875  0.164288  ...   2.9
# 2016-01-01 03:00:00+00:00  4.664023  2.546875  10.546875  0.164239  ...   2.0
# 2016-01-01 04:00:00+00:00  4.566289  2.546875  10.546875  0.164199  ...   1.9
# ...                             ...       ...        ...       ...  ...   ...
# 2016-12-31 19:00:00+00:00  7.098086  2.550781  10.550781  0.164608  ...   1.9
# 2016-12-31 20:00:00+00:00  7.083867  2.550781  10.550781  0.164577  ...   1.9
# 2016-12-31 21:00:00+00:00  7.122773  2.546875  10.546875  0.164536  ...   2.9
# 2016-12-31 22:00:00+00:00  7.221172  2.546875  10.546875  0.164504  ...   3.9
# 2016-12-31 23:00:00+00:00  7.283984  2.546875  10.546875  0.164468  ...   3.8
#
#                            humidity  dew  windspeed  winddir  pressure  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00    100.00  1.9        4.4    180.0       NaN
# 2016-01-01 01:00:00+00:00     93.62  1.9        5.6    196.0       NaN
# 2016-01-01 02:00:00+00:00     94.10  2.0        6.7    230.0       NaN
# 2016-01-01 03:00:00+00:00     94.06  1.1        5.1    218.0       NaN
# 2016-01-01 04:00:00+00:00     93.61  1.0        1.9    202.0       NaN
# ...                             ...  ...        ...      ...       ...
# 2016-12-31 19:00:00+00:00     98.45  1.6       15.0    240.0       NaN
# 2016-12-31 20:00:00+00:00     98.46  1.7       14.2    239.0       NaN
# 2016-12-31 21:00:00+00:00     92.66  1.9       16.6    244.0       NaN
# 2016-12-31 22:00:00+00:00     87.69  2.0       13.2    226.0       NaN
# 2016-12-31 23:00:00+00:00     87.23  1.9       14.8    226.0       NaN
#
#                            visibility  cloudcover  skyType  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00         0.4        98.4      1.0
# 2016-01-01 01:00:00+00:00         0.3        59.2      2.0
# 2016-01-01 02:00:00+00:00         1.1        98.4      1.0
# 2016-01-01 03:00:00+00:00         1.3        98.4      1.0
# 2016-01-01 04:00:00+00:00         2.1        13.8      0.0
# ...                               ...         ...      ...
# 2016-12-31 19:00:00+00:00         3.9        98.4      1.0
# 2016-12-31 20:00:00+00:00         4.3        98.4      1.0
# 2016-12-31 21:00:00+00:00         8.0        98.4      1.0
# 2016-12-31 22:00:00+00:00        10.0        98.4      1.0
# 2016-12-31 23:00:00+00:00        10.0        98.4      1.0
#
#                            total_renewable_generation
# utc_timestamp
# 2016-01-01 00:00:00+00:00                      8579.0
# 2016-01-01 01:00:00+00:00                      8542.0
# 2016-01-01 02:00:00+00:00                      8443.0
# 2016-01-01 03:00:00+00:00                      8295.0
# 2016-01-01 04:00:00+00:00                      7319.0
# ...                                               ...
# 2016-12-31 19:00:00+00:00                     15303.0
# 2016-12-31 20:00:00+00:00                     15354.0
# 2016-12-31 21:00:00+00:00                     14847.0
# 2016-12-31 22:00:00+00:00                     15056.0
# 2016-12-31 23:00:00+00:00                     15422.0
#
# [8710 rows x 25 columns]

# %% [markdown]
# Further evidence for the apparent correlation between certain quantities can be obtained from the following plots, in which the wind and solar generation is shown as a function of the several weather quantities.

# %%
sns.pairplot(thesis_dataset, x_vars=['v1', 'v2', 'v_50m', 'z0'], y_vars=['DE_wind_generation_actual_x'])

# %%
sns.pairplot(thesis_dataset, x_vars=['SWTDN', 'SWGDN', 'T', 'rho', 'p'], y_vars=['DE_wind_generation_actual_x'])

# %%
sns.pairplot(thesis_dataset, x_vars=['v1', 'v2', 'v_50m', 'z0'], y_vars=['DE_solar_generation_actual_x'])

# %%
sns.pairplot(thesis_dataset, x_vars=['SWTDN', 'SWGDN', 'T', 'rho', 'p'], y_vars=['DE_solar_generation_actual_x'])

# %% [markdown]
# There seems to be a linear relation between the wind generation and the wind velocities v1, v2 and v_50m, but not the other quantities.

# %%
sns.jointplot(x='v1', y='DE_wind_generation_actual_x', data=thesis_dataset, kind='reg')
sns.jointplot(x='v2', y='DE_wind_generation_actual_x', data=thesis_dataset, kind='reg')
sns.jointplot(x='v_50m', y='DE_wind_generation_actual_x', data=thesis_dataset, kind='reg')
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Similarly, there seems to be a linear relation between the solar generation and the top-of-the-atmosphere and ground radiation.

# %%
sns.jointplot(x='SWTDN', y='DE_solar_generation_actual_x', data=thesis_dataset, kind='reg')
sns.jointplot(x='SWGDN', y='DE_solar_generation_actual_x', data=thesis_dataset, kind='reg')
sns.jointplot(x='T', y='DE_solar_generation_actual_x', data=thesis_dataset, kind='reg')
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
thesis_dataset[['v1', 'v2', 'v_50m', 'z0', 'SWTDN', 'SWGDN', 'T', 'DE_wind_generation_actual_x', 'DE_solar_generation_actual_x']].describe()
# Out:
#                 v1           v2        v_50m           z0        SWTDN  \
# count  8710.000000  8710.000000  8710.000000  8710.000000  8710.000000
# mean      2.942022     4.293778     6.050977     0.200226   278.161445
# std       1.197014     1.613602     2.090126     0.032327   359.492630
# min       0.746523     1.345508     1.958984     0.140880     0.000000
# 25%       2.068818     3.137695     4.625986     0.170408     0.000000
# 50%       2.714980     3.942969     5.710977     0.211835    31.686710
# 75%       3.574941     5.102090     7.084453     0.230068   523.566528
# max       7.927695    11.164297    14.922969     0.235163  1160.939453
#
#              SWGDN            T  DE_wind_generation_actual_x  \
# count  8710.000000  8710.000000                  8710.000000
# mean    146.149373   282.367904                  8717.957979
# std     212.568632     7.600473                  6848.673246
# min       0.000000   264.596945                   135.000000
# 25%       0.000000   276.034470                  3586.500000
# 50%       7.899137   281.238663                  6903.000000
# 75%     243.067932   288.708031                 11704.250000
# max     885.725586   301.845276                 33626.000000
#
#        DE_solar_generation_actual_x
# count                   8710.000000
# mean                    3946.116073
# std                     6041.485045
# min                        0.000000
# 25%                        0.000000
# 50%                      123.500000
# 75%                     6287.750000
# max                    26055.000000

# %% [markdown]
# ## 3. Linear regression algorithm

# %% [markdown]
# Given the observations above, I’m going to try a linear regression algorithm in order to predict the wind and solar generation from some of the above weather quantities.

# %%
# import necessary modules
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# instantiate LinearRegression
lr = LinearRegression()

# %% [markdown]
# ## 3.1. Wind generation

# %% [markdown]
# To predict the wind generation, we construct the features matrix `X_wind` with the features v1, v2 and v_50m, and the target `Y_wind` with actual wind generation.

# %%
X_wind = thesis_dataset[['v1', 'v2', 'v_50m', 'z0']]
y_wind = thesis_dataset['DE_wind_generation_actual_x']

# %% [markdown]
# Then, we implement a 5-fold CV procedure.

# %%
scores_wind = cross_val_score(lr, X_wind, y_wind, cv=5)
print(scores_wind, "\naverage =", np.mean(scores_wind))
# Out:
# [0.84708392 0.88861781 0.81771924 0.88321327 0.8573129 ]
# average = 0.8587894275260812

# %% [markdown]
# The first line contains the five values of $R^2$ for each of the 5 folds in the cross validation procedure, whereas the second line is their average. We see that our linear model has an $R^2$ of approximately 0.86, which is quite good for such a simple model! We can make good predictions about the wind generation in Germany in 2016 given only the wind velocities at different heights.

# %% [markdown]
# ## 3.2. Solar generation

# %% [markdown]
# To predict the solar generation, we follow a very similar procedure. We again construct the features matrix `X_solar`, but now with the features SWTDN, SWGDN and T, and the target `Y_solar` with actual solar generation.

# %%
X_solar = thesis_dataset[['SWTDN', 'SWGDN', 'T']]
y_solar = thesis_dataset['DE_solar_generation_actual_x']

# %% [markdown]
# Then, we implement a 5-fold CV procedure:

# %%
scores_solar = cross_val_score(lr, X_solar, y_solar, cv=5)
print(scores_solar, "\naverage =", np.mean(scores_solar))
# Out:
# [0.88997699 0.95302251 0.95591745 0.95045437 0.87382238]
# average = 0.9246387377264398

# %% [markdown]
# We get an even better value of $R^2$! We can make good predictions about the solar generation in Germany in 2016 given only the temperature and top-of-the-atmosphere and ground radiation.

# %% [markdown]
# # 3.3 Solar and Wind Combined

# %% [markdown]
# Just trying to predict if there weather variables combined could give better accuracy for predicting the overall renewable energy where X is all the weather variables deemed useful for renewable prediction.

# %%
X = thesis_dataset[['v1', 'v2', 'v_50m', 'z0', 'SWTDN', 'SWGDN', 'T']]
y = thesis_dataset['DE_solar_generation_actual_x'] + thesis_dataset['DE_wind_generation_actual_x']

# %%
scores_overall = cross_val_score(lr, X, y, cv=5)
print(scores_solar, "\naverage =", np.mean(scores_overall))
# Out:
# [0.88997699 0.95302251 0.95591745 0.95045437 0.87382238]
# average = 0.8703756669231524

# %% [markdown]
# We get an average score for $R^2$! that is less than $\frac{92(Solar) + 86(Wind)}{2} = 89$. So it could signified that global model couldn't be created by considering all the variables for predicting solar and wind. But instead a ensemble or stacked model that incorporates different results could give much better score.

# %% [markdown]
# # 4. Combining with the Forecast Data

# %%
#thesis_dataset.reset_index(inplace=True)
thesis_dataset = (pd.merge(thesis_dataset, weather_forecast_data, left_on='utc_timestamp', right_on='utc_timestamp', how='left'))
                  #.set_index('utc_timestamp'))
thesis_dataset = thesis_dataset.set_index('utc_timestamp')
#cols_to_drop = ['utc_timestamp', 'de_datetime']
#thesis_dataset.drop(
#    [col for col in cols_to_drop if col in thesis_dataset.columns],
#    axis=1,
#    inplace=True,
##)
#thesis_dataset.drop(['utc_datetime', 'de_datetime'], axis = 1, inplace=True)

# %%
thesis_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8711 entries, 0 to 8710
# Data columns (total 52 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   level_0                       8711 non-null   int64
#  1   utc_timestamp                 8711 non-null   datetime64[ns, UTC]
#  2   index                         8711 non-null   int64
#  3   DE_wind_generation_actual_x   8711 non-null   float64
#  4   DE_solar_generation_actual_x  8711 non-null   float64
#  5   DE_wind_generation_actual_y   8711 non-null   float64
#  6   DE_solar_generation_actual_y  8711 non-null   float64
#  7   v1_x                          8711 non-null   float64
#  8   v2_x                          8711 non-null   float64
#  9   v_50m_x                       8711 non-null   float64
#  10  h1_x                          8711 non-null   float64
#  11  h2_x                          8711 non-null   float64
#  12  z0_x                          8711 non-null   float64
#  13  SWTDN_x                       8711 non-null   float64
#  14  SWGDN_x                       8711 non-null   float64
#  15  T_x                           8711 non-null   float64
#  16  rho_x                         8711 non-null   float64
#  17  p_x                           8711 non-null   float64
#  18  temp_x                        8710 non-null   float64
#  19  humidity_x                    8710 non-null   float64
#  20  dew_x                         8710 non-null   float64
#  21  windspeed_x                   8710 non-null   float64
#  22  winddir_x                     8710 non-null   float64
#  23  pressure_x                    216 non-null    float64
#  24  visibility_x                  8710 non-null   float64
#  25  cloudcover_x                  8710 non-null   float64
#  26  skyType_x                     8710 non-null   float64
#  27  total_renewable_generation_x  8711 non-null   float64
#  28  DE_wind_generation_actual     8711 non-null   float64
#  29  DE_solar_generation_actual    8711 non-null   float64
#  30  v1_y                          8711 non-null   float64
#  31  v2_y                          8711 non-null   float64
#  32  v_50m_y                       8711 non-null   float64
#  33  h1_y                          8711 non-null   float64
#  34  h2_y                          8711 non-null   float64
#  35  z0_y                          8711 non-null   float64
#  36  SWTDN_y                       8711 non-null   float64
#  37  SWGDN_y                       8711 non-null   float64
#  38  T_y                           8711 non-null   float64
#  39  rho_y                         8711 non-null   float64
#  40  p_y                           8711 non-null   float64
#  41  temp_y                        8710 non-null   float64
#  42  humidity_y                    8710 non-null   float64
#  43  dew_y                         8710 non-null   float64
#  44  windspeed_y                   8710 non-null   float64
#  45  winddir_y                     8710 non-null   float64
#  46  pressure_y                    216 non-null    float64
#  47  visibility_y                  8710 non-null   float64
#  48  cloudcover_y                  8710 non-null   float64
#  49  conditions                    8710 non-null   object
#  50  skyType_y                     8710 non-null   float64
#  51  total_renewable_generation_y  8711 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(48), int64(2), object(1)
# memory usage: 3.5+ MB

# %%
thesis_dataset.describe()
# Out:
#            level_0        index  DE_wind_generation_actual_x  \
# count  8711.000000  8711.000000                  8711.000000
# mean   4355.000000  4354.829411                  8717.896568
# std    2514.793431  2514.548368                  6848.282483
# min       0.000000     0.000000                   135.000000
# 25%    2177.500000  2177.500000                  3587.000000
# 50%    4355.000000  4355.000000                  6904.000000
# 75%    6532.500000  6532.500000                 11703.500000
# max    8710.000000  8709.000000                 33626.000000
#
#        DE_solar_generation_actual_x  DE_wind_generation_actual_y  \
# count                   8711.000000                  8711.000000
# mean                    3945.663070                  8717.896568
# std                     6041.286172                  6848.282483
# min                        0.000000                   135.000000
# 25%                        0.000000                  3587.000000
# 50%                      123.000000                  6904.000000
# 75%                     6287.500000                 11703.500000
# max                    26055.000000                 33626.000000
#
#        DE_solar_generation_actual_y         v1_x         v2_x      v_50m_x  \
# count                   8711.000000  8711.000000  8711.000000  8711.000000
# mean                    3945.663070     2.941975     4.293732     6.050961
# std                     6041.286172     1.196953     1.613515     2.090007
# min                        0.000000     0.746523     1.345508     1.958984
# 25%                        0.000000     2.068887     3.137734     4.626191
# 50%                      123.000000     2.714648     3.942500     5.711445
# 75%                     6287.500000     3.574883     5.102070     7.084414
# max                    26055.000000     7.927695    11.164297    14.922969
#
#               h1_x  ...       temp_y   humidity_y        dew_y  windspeed_y  \
# count  8711.000000  ...  8710.000000  8710.000000  8710.000000  8710.000000
# mean      2.692196  ...    10.633800    72.806055     5.211917    12.533410
# std       0.131461  ...     8.392887    19.060688     6.115717     7.193215
# min       2.457031  ...   -11.100000    13.530000   -14.900000     0.000000
# 25%       2.582031  ...     4.000000    60.342500     0.900000     7.500000
# 50%       2.722656  ...     9.700000    76.335000     5.100000    11.400000
# 75%       2.812500  ...    17.400000    87.890000    10.000000    16.400000
# max       2.832031  ...    34.900000   100.000000    20.000000    60.700000
#
#          winddir_y   pressure_y  visibility_y  cloudcover_y    skyType_y  \
# count  8710.000000   216.000000   8710.000000   8710.000000  8710.000000
# mean    189.472044  1009.766667      9.257245     45.320804     1.043513
# std      94.345533     9.379919      1.970650     42.020461     0.951005
# min       0.000000   998.600000      0.000000      0.000000     0.000000
# 25%     105.000000  1004.300000     10.000000      0.000000     0.000000
# 50%     209.000000  1004.400000     10.000000     46.700000     1.000000
# 75%     269.000000  1021.500000     10.000000     88.900000     2.000000
# max     360.000000  1022.900000     10.000000    100.000000     2.000000
#
#        total_renewable_generation_y
# count                   8711.000000
# mean                   12663.559637
# std                     8381.763910
# min                      374.000000
# 25%                     5927.000000
# 50%                    10712.000000
# 75%                    17853.000000
# max                    43859.000000
#
# [8 rows x 50 columns]

# %%
# create plot
plt.plot(thesis_dataset.index, thesis_dataset['humidity_x'])
plt.title('Humidity levels over the year')
plt.xlim(pd.Timestamp('2016-01-01'), pd.Timestamp('2017-01-01'))
# Out:
# (16801.0, 17167.0)

# %%
# create plot
plt.plot(thesis_dataset.index, thesis_dataset['temp_x'])
plt.title('Temperature levels over the year')
plt.xlim(pd.Timestamp('2016-01-01'), pd.Timestamp('2017-01-01'))
# Out:
# (16801.0, 17167.0)

# %%
# create plot
plt.plot(thesis_dataset.index, thesis_dataset['pressure_x'].ffill())
plt.title('Sea Level Pressure over the year')
plt.xlim(pd.Timestamp('2016-01-01'), pd.Timestamp('2017-01-01'))
# Out:
# (16801.0, 17167.0)

# %%
# create plot
plt.plot(thesis_dataset.index, thesis_dataset['dew'])
plt.title('Dew Point over the year')
plt.xlim(pd.Timestamp('2016-01-01'), pd.Timestamp('2017-01-01'))
# Out:
# (735964.0, 736330.0)

# %%
thesis_dataset['total_renewable_generation'] = thesis_dataset['DE_wind_generation_actual'] + thesis_dataset['DE_solar_generation_actual']
thesis_dataset.to_csv('data/final_thesis_dataset.csv')
