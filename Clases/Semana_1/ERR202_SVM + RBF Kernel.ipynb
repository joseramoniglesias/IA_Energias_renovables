# %% [markdown]
# # Predicting Solar Generation from Weather Forecasts Using Machine Learning

# %%
# Basic Data Science Packages
import numpy as np
import pandas as pd

#ML scikit learn SVR
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
  
#Plotting graph
import matplotlib.pyplot as plt

#Normalization of data
from sklearn.preprocessing import StandardScaler

#Utility Module for computing and displaying metrics
from utility_functions import metrics

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Import Data
# - Fetch the first 70% records as train and rest as test
#     - 8711 * 70% = 6098 records from the start (Train)
#     - 8711 - 6098 = 2613 remaining records as (Test)

# %%
thesis_dataset = pd.read_csv('data/final_thesis_dataset.csv',parse_dates=[0], index_col=0)

train = thesis_dataset[:6098] 
test = thesis_dataset[6098:] 

X_solar_train = train[['SWTDN', 'SWGDN', 'T']]
y_solar_train = train['DE_solar_generation_actual']
X_solar_test = test[['SWTDN', 'SWGDN', 'T']]
y_solar_test = test['DE_solar_generation_actual']

X_wind_train = train[['v1', 'v2', 'v_50m', 'z0']]
y_wind_train = train['DE_wind_generation_actual']
X_wind_test = test[['v1', 'v2', 'v_50m', 'z0']]
y_wind_test = test['DE_wind_generation_actual']

# %% [markdown]
# ## Collating a dictionary of the suitable parameter value for the GridSearch to find optimal settings

# %%
# defining parameter range
param_grid = {'C': [1, 10, 100, 1000], 
              'gamma': [0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']} 

solar_grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3, return_train_score=True)
  
# fitting the model for grid search
solar_grid.fit(X_solar_train, y_solar_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END C=1, gamma=0.1, kernel=rbf;, score=(train=-0.328, test=0.073) total time=   1.3s
# [CV 2/5] END C=1, gamma=0.1, kernel=rbf;, score=(train=-0.371, test=-0.271) total time=   1.3s
# [CV 3/5] END C=1, gamma=0.1, kernel=rbf;, score=(train=-0.355, test=-0.567) total time=   1.3s
# [CV 4/5] END C=1, gamma=0.1, kernel=rbf;, score=(train=-0.337, test=-0.685) total time=   1.3s
# [CV 5/5] END C=1, gamma=0.1, kernel=rbf;, score=(train=-0.339, test=-0.546) total time=   1.2s
# [CV 1/5] END C=1, gamma=0.01, kernel=rbf;, score=(train=-0.319, test=0.213) total time=   1.3s
# [CV 2/5] END C=1, gamma=0.01, kernel=rbf;, score=(train=-0.311, test=-0.196) total time=   1.3s
# [CV 3/5] END C=1, gamma=0.01, kernel=rbf;, score=(train=-0.274, test=-0.477) total time=   1.2s
# [CV 4/5] END C=1, gamma=0.01, kernel=rbf;, score=(train=-0.242, test=-0.576) total time=   1.3s
# [CV 5/5] END C=1, gamma=0.01, kernel=rbf;, score=(train=-0.243, test=-0.449) total time=   1.3s
# [CV 1/5] END C=1, gamma=0.001, kernel=rbf;, score=(train=-0.266, test=0.355) total time=   1.3s
# [CV 2/5] END C=1, gamma=0.001, kernel=rbf;, score=(train=-0.223, test=-0.089) total time=   1.3s
# [CV 3/5] END C=1, gamma=0.001, kernel=rbf;, score=(train=-0.180, test=-0.373) total time=   1.3s
# [CV 4/5] END C=1, gamma=0.001, kernel=rbf;, score=(train=-0.159, test=-0.481) total time=   1.3s
# [CV 5/5] END C=1, gamma=0.001, kernel=rbf;, score=(train=-0.171, test=-0.375) total time=   1.3s
# [CV 1/5] END C=1, gamma=0.0001, kernel=rbf;, score=(train=-0.188, test=0.471) total time=   1.7s
# [CV 2/5] END C=1, gamma=0.0001, kernel=rbf;, score=(train=-0.158, test=-0.010) total time=   1.4s
# [CV 3/5] END C=1, gamma=0.0001, kernel=rbf;, score=(train=-0.117, test=-0.305) total time=   1.4s
# [CV 4/5] END C=1, gamma=0.0001, kernel=rbf;, score=(train=-0.099, test=-0.418) total time=   1.4s
# [CV 5/5] END C=1, gamma=0.0001, kernel=rbf;, score=(train=-0.113, test=-0.315) total time=   1.5s
# [CV 1/5] END C=10, gamma=0.1, kernel=rbf;, score=(train=-0.047, test=0.230) total time=   2.1s
# [CV 2/5] END C=10, gamma=0.1, kernel=rbf;, score=(train=-0.083, test=0.074) total time=   1.3s
# [CV 3/5] END C=10, gamma=0.1, kernel=rbf;, score=(train=-0.047, test=-0.221) total time=   1.3s
# [CV 4/5] END C=10, gamma=0.1, kernel=rbf;, score=(train=-0.036, test=-0.334) total time=   1.3s
# [CV 5/5] END C=10, gamma=0.1, kernel=rbf;, score=(train=-0.034, test=-0.229) total time=   1.3s
# [CV 1/5] END C=10, gamma=0.01, kernel=rbf;, score=(train=0.179, test=0.065) total time=   1.4s
# [CV 2/5] END C=10, gamma=0.01, kernel=rbf;, score=(train=0.105, test=0.279) total time=   1.3s
# [CV 3/5] END C=10, gamma=0.01, kernel=rbf;, score=(train=0.118, test=-0.029) total time=   1.4s
# [CV 4/5] END C=10, gamma=0.01, kernel=rbf;, score=(train=0.138, test=-0.123) total time=   1.3s
# [CV 5/5] END C=10, gamma=0.01, kernel=rbf;, score=(train=0.139, test=-0.036) total time=   1.3s
# [CV 1/5] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.355, test=0.048) total time=   1.3s
# [CV 2/5] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.279, test=0.457) total time=   1.3s
# [CV 3/5] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.273, test=0.146) total time=   1.3s
# [CV 4/5] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.290, test=0.062) total time=   1.2s
# [CV 5/5] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.285, test=0.122) total time=   1.3s
# [CV 1/5] END C=10, gamma=0.0001, kernel=rbf;, score=(train=0.606, test=0.632) total time=   1.4s
# [CV 2/5] END C=10, gamma=0.0001, kernel=rbf;, score=(train=0.563, test=0.722) total time=   1.3s
# [CV 3/5] END C=10, gamma=0.0001, kernel=rbf;, score=(train=0.532, test=0.441) total time=   1.4s
# [CV 4/5] END C=10, gamma=0.0001, kernel=rbf;, score=(train=0.540, test=0.345) total time=   1.3s
# [CV 5/5] END C=10, gamma=0.0001, kernel=rbf;, score=(train=0.535, test=0.409) total time=   1.3s
# [CV 1/5] END C=100, gamma=0.1, kernel=rbf;, score=(train=0.347, test=-1.362) total time=   1.5s
# [CV 2/5] END C=100, gamma=0.1, kernel=rbf;, score=(train=0.270, test=0.409) total time=   1.6s
# [CV 3/5] END C=100, gamma=0.1, kernel=rbf;, score=(train=0.267, test=0.138) total time=   1.7s
# [CV 4/5] END C=100, gamma=0.1, kernel=rbf;, score=(train=0.277, test=0.051) total time=   1.7s
# [CV 5/5] END C=100, gamma=0.1, kernel=rbf;, score=(train=0.268, test=0.109) total time=   1.6s
# [CV 1/5] END C=100, gamma=0.01, kernel=rbf;, score=(train=0.476, test=-1.040) total time=   1.3s
# [CV 2/5] END C=100, gamma=0.01, kernel=rbf;, score=(train=0.408, test=0.532) total time=   1.3s
# [CV 3/5] END C=100, gamma=0.01, kernel=rbf;, score=(train=0.399, test=0.288) total time=   1.5s
# [CV 4/5] END C=100, gamma=0.01, kernel=rbf;, score=(train=0.405, test=0.206) total time=   1.4s
# [CV 5/5] END C=100, gamma=0.01, kernel=rbf;, score=(train=0.400, test=0.247) total time=   1.4s
# [CV 1/5] END C=100, gamma=0.001, kernel=rbf;, score=(train=0.757, test=0.340) total time=   1.3s
# [CV 2/5] END C=100, gamma=0.001, kernel=rbf;, score=(train=0.734, test=0.816) total time=   1.3s
# [CV 3/5] END C=100, gamma=0.001, kernel=rbf;, score=(train=0.704, test=0.625) total time=   1.3s
# [CV 4/5] END C=100, gamma=0.001, kernel=rbf;, score=(train=0.694, test=0.546) total time=   1.3s
# [CV 5/5] END C=100, gamma=0.001, kernel=rbf;, score=(train=0.701, test=0.590) total time=   1.3s
# [CV 1/5] END C=100, gamma=0.0001, kernel=rbf;, score=(train=0.941, test=0.779) total time=   1.3s
# [CV 2/5] END C=100, gamma=0.0001, kernel=rbf;, score=(train=0.944, test=0.918) total time=   1.3s
# [CV 3/5] END C=100, gamma=0.0001, kernel=rbf;, score=(train=0.935, test=0.909) total time=   1.3s
# [CV 4/5] END C=100, gamma=0.0001, kernel=rbf;, score=(train=0.929, test=0.867) total time=   1.3s
# [CV 5/5] END C=100, gamma=0.0001, kernel=rbf;, score=(train=0.922, test=0.909) total time=   1.3s
# [CV 1/5] END C=1000, gamma=0.1, kernel=rbf;, score=(train=0.578, test=-1.982) total time=   8.4s
# [CV 2/5] END C=1000, gamma=0.1, kernel=rbf;, score=(train=0.526, test=0.510) total time=   8.0s
# [CV 3/5] END C=1000, gamma=0.1, kernel=rbf;, score=(train=0.522, test=0.302) total time=   8.1s
# [CV 4/5] END C=1000, gamma=0.1, kernel=rbf;, score=(train=0.518, test=0.220) total time=   8.7s
# [CV 5/5] END C=1000, gamma=0.1, kernel=rbf;, score=(train=0.519, test=0.265) total time=   7.3s
# [CV 1/5] END C=1000, gamma=0.01, kernel=rbf;, score=(train=0.802, test=-0.570) total time=   3.2s
# [CV 2/5] END C=1000, gamma=0.01, kernel=rbf;, score=(train=0.781, test=0.749) total time=   3.1s
# [CV 3/5] END C=1000, gamma=0.01, kernel=rbf;, score=(train=0.762, test=0.596) total time=   6.6s
# [CV 4/5] END C=1000, gamma=0.01, kernel=rbf;, score=(train=0.739, test=0.529) total time=   7.6s
# [CV 5/5] END C=1000, gamma=0.01, kernel=rbf;, score=(train=0.760, test=0.557) total time=   6.2s
# [CV 1/5] END C=1000, gamma=0.001, kernel=rbf;, score=(train=0.963, test=0.683) total time=   1.6s
# [CV 2/5] END C=1000, gamma=0.001, kernel=rbf;, score=(train=0.966, test=0.911) total time=   1.7s
# [CV 3/5] END C=1000, gamma=0.001, kernel=rbf;, score=(train=0.960, test=0.901) total time=   1.9s
# [CV 4/5] END C=1000, gamma=0.001, kernel=rbf;, score=(train=0.958, test=0.864) total time=   2.0s
# [CV 5/5] END C=1000, gamma=0.001, kernel=rbf;, score=(train=0.952, test=0.931) total time=   1.8s
# [CV 1/5] END C=1000, gamma=0.0001, kernel=rbf;, score=(train=0.967, test=0.833) total time=   1.4s
# [CV 2/5] END C=1000, gamma=0.0001, kernel=rbf;, score=(train=0.970, test=0.929) total time=   1.6s
# [CV 3/5] END C=1000, gamma=0.0001, kernel=rbf;, score=(train=0.968, test=0.956) total time=   1.5s
# [CV 4/5] END C=1000, gamma=0.0001, kernel=rbf;, score=(train=0.964, test=0.951) total time=   1.5s
# [CV 5/5] END C=1000, gamma=0.0001, kernel=rbf;, score=(train=0.962, test=0.968) total time=   1.5s
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [1, 10, 100, 1000],
#                          'gamma': [0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              return_train_score=True, verbose=3)

# %%
# print best parameter after tuning
print(solar_grid.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(solar_grid.best_estimator_)
# Out:
# {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# SVR(C=1000, gamma=0.0001)

# %% [markdown]
# ## Running predictions on the best model decided and Plotting them side by side

# %%
train_solar_pred = solar_grid.predict(X_solar_train)
test_solar_pred = solar_grid.predict(X_solar_test)

df = thesis_dataset[['DE_solar_generation_actual']]

train_df = train[['DE_solar_generation_actual']]
train_df.loc[:, 'DE_solar_generation_actual'] = train_solar_pred

test_df = test[['DE_solar_generation_actual']]
test_df.loc[:, 'DE_solar_generation_actual'] = test_solar_pred

# Plot all predictions
inversetransform, =plt.plot(df, label = 'Actual')
trainpredx, =plt.plot(train_df, color='orange', label = 'Train')
testpredx, =plt.plot(test_df, color='green', label = 'Test')
plt.xlabel('Date')
plt.ylabel('Solar Output')
plt.legend(loc="upper right")
plt.title("Predicted vs. Actual Solar Generation")
plt.show()

# %% [markdown]
# ## Regression Metrics for Solar Data

# %%
#metrics('svm+rbf', test[['DE_solar_generation_actual']], test_solar_pred)
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
import numpy as np
import pandas as pd

def metrics(model_name, actual, predictions):
    # Convert to 1D arrays (handles DataFrame, Series, or list)
    actual = np.asarray(actual).ravel()
    predictions = np.asarray(predictions).ravel()

    mae = mean_absolute_error(actual, predictions)
    rmse = root_mean_squared_error(actual, predictions)   # New sklearn way
    mse = rmse ** 2
    r2 = r2_score(actual, predictions)

# %% [markdown]
# # Performing same tuning for Wind Data

# %%
# defining parameter range
param_grid = {'C': [1, 10, 100, 1000], 
              'gamma': [0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']} 

wind_grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3, return_train_score=True)
  
# fitting the model for grid search
wind_grid.fit(X_wind_train, y_wind_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END C=1, gamma=0.1, kernel=rbf;, score=(train=0.156, test=-0.689) total time=   1.2s
# [CV 2/5] END C=1, gamma=0.1, kernel=rbf;, score=(train=0.118, test=0.081) total time=   1.1s
# [CV 3/5] END C=1, gamma=0.1, kernel=rbf;, score=(train=0.087, test=0.136) total time=   1.1s
# [CV 4/5] END C=1, gamma=0.1, kernel=rbf;, score=(train=0.117, test=0.205) total time=   1.2s
# [CV 5/5] END C=1, gamma=0.1, kernel=rbf;, score=(train=0.122, test=0.051) total time=   1.1s
# [CV 1/5] END C=1, gamma=0.01, kernel=rbf;, score=(train=0.028, test=-0.712) total time=   1.2s
# [CV 2/5] END C=1, gamma=0.01, kernel=rbf;, score=(train=0.041, test=0.003) total time=   1.2s
# [CV 3/5] END C=1, gamma=0.01, kernel=rbf;, score=(train=0.022, test=-0.042) total time=   1.2s
# [CV 4/5] END C=1, gamma=0.01, kernel=rbf;, score=(train=0.055, test=0.024) total time=   1.2s
# [CV 5/5] END C=1, gamma=0.01, kernel=rbf;, score=(train=0.054, test=-0.177) total time=   1.2s
# [CV 1/5] END C=1, gamma=0.001, kernel=rbf;, score=(train=-0.051, test=-0.812) total time=   1.2s
# [CV 2/5] END C=1, gamma=0.001, kernel=rbf;, score=(train=-0.050, test=-0.091) total time=   1.2s
# [CV 3/5] END C=1, gamma=0.001, kernel=rbf;, score=(train=-0.067, test=-0.146) total time=   1.2s
# [CV 4/5] END C=1, gamma=0.001, kernel=rbf;, score=(train=-0.037, test=-0.089) total time=   1.2s
# [CV 5/5] END C=1, gamma=0.001, kernel=rbf;, score=(train=-0.038, test=-0.324) total time=   1.2s
# [CV 1/5] END C=1, gamma=0.0001, kernel=rbf;, score=(train=-0.063, test=-0.833) total time=   1.2s
# [CV 2/5] END C=1, gamma=0.0001, kernel=rbf;, score=(train=-0.065, test=-0.107) total time=   1.2s
# [CV 3/5] END C=1, gamma=0.0001, kernel=rbf;, score=(train=-0.081, test=-0.158) total time=   1.2s
# [CV 4/5] END C=1, gamma=0.0001, kernel=rbf;, score=(train=-0.052, test=-0.105) total time=   1.2s
# [CV 5/5] END C=1, gamma=0.0001, kernel=rbf;, score=(train=-0.053, test=-0.346) total time=   1.2s
# [CV 1/5] END C=10, gamma=0.1, kernel=rbf;, score=(train=0.648, test=-0.115) total time=   1.1s
# [CV 2/5] END C=10, gamma=0.1, kernel=rbf;, score=(train=0.594, test=0.580) total time=   1.1s
# [CV 3/5] END C=10, gamma=0.1, kernel=rbf;, score=(train=0.596, test=0.784) total time=   1.1s
# [CV 4/5] END C=10, gamma=0.1, kernel=rbf;, score=(train=0.602, test=0.795) total time=   1.2s
# [CV 5/5] END C=10, gamma=0.1, kernel=rbf;, score=(train=0.610, test=0.790) total time=   1.1s
# [CV 1/5] END C=10, gamma=0.01, kernel=rbf;, score=(train=0.565, test=0.085) total time=   1.2s
# [CV 2/5] END C=10, gamma=0.01, kernel=rbf;, score=(train=0.613, test=0.593) total time=   1.2s
# [CV 3/5] END C=10, gamma=0.01, kernel=rbf;, score=(train=0.617, test=0.615) total time=   1.2s
# [CV 4/5] END C=10, gamma=0.01, kernel=rbf;, score=(train=0.627, test=0.698) total time=   1.2s
# [CV 5/5] END C=10, gamma=0.01, kernel=rbf;, score=(train=0.627, test=0.680) total time=   1.2s
# [CV 1/5] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.057, test=-0.621) total time=   1.2s
# [CV 2/5] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.095, test=0.054) total time=   1.2s
# [CV 3/5] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.079, test=-0.005) total time=   1.2s
# [CV 4/5] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.108, test=0.067) total time=   1.2s
# [CV 5/5] END C=10, gamma=0.001, kernel=rbf;, score=(train=0.107, test=-0.118) total time=   1.2s
# [CV 1/5] END C=10, gamma=0.0001, kernel=rbf;, score=(train=-0.051, test=-0.811) total time=   1.2s
# [CV 2/5] END C=10, gamma=0.0001, kernel=rbf;, score=(train=-0.049, test=-0.090) total time=   1.2s
# [CV 3/5] END C=10, gamma=0.0001, kernel=rbf;, score=(train=-0.066, test=-0.146) total time=   1.2s
# [CV 4/5] END C=10, gamma=0.0001, kernel=rbf;, score=(train=-0.036, test=-0.088) total time=   1.2s
# [CV 5/5] END C=10, gamma=0.0001, kernel=rbf;, score=(train=-0.037, test=-0.323) total time=   1.2s
# [CV 1/5] END C=100, gamma=0.1, kernel=rbf;, score=(train=0.864, test=0.568) total time=   1.1s
# [CV 2/5] END C=100, gamma=0.1, kernel=rbf;, score=(train=0.908, test=0.897) total time=   1.1s
# [CV 3/5] END C=100, gamma=0.1, kernel=rbf;, score=(train=0.914, test=0.881) total time=   1.1s
# [CV 4/5] END C=100, gamma=0.1, kernel=rbf;, score=(train=0.911, test=0.879) total time=   1.1s
# [CV 5/5] END C=100, gamma=0.1, kernel=rbf;, score=(train=0.910, test=0.872) total time=   1.1s
# [CV 1/5] END C=100, gamma=0.01, kernel=rbf;, score=(train=0.884, test=0.823) total time=   1.1s
# [CV 2/5] END C=100, gamma=0.01, kernel=rbf;, score=(train=0.920, test=0.901) total time=   1.1s
# [CV 3/5] END C=100, gamma=0.01, kernel=rbf;, score=(train=0.923, test=0.867) total time=   1.1s
# [CV 4/5] END C=100, gamma=0.01, kernel=rbf;, score=(train=0.918, test=0.871) total time=   1.1s
# [CV 5/5] END C=100, gamma=0.01, kernel=rbf;, score=(train=0.916, test=0.873) total time=   1.2s
# [CV 1/5] END C=100, gamma=0.001, kernel=rbf;, score=(train=0.674, test=0.507) total time=   1.2s
# [CV 2/5] END C=100, gamma=0.001, kernel=rbf;, score=(train=0.783, test=0.751) total time=   1.2s
# [CV 3/5] END C=100, gamma=0.001, kernel=rbf;, score=(train=0.788, test=0.699) total time=   1.2s
# [CV 4/5] END C=100, gamma=0.001, kernel=rbf;, score=(train=0.796, test=0.772) total time=   1.2s
# [CV 5/5] END C=100, gamma=0.001, kernel=rbf;, score=(train=0.787, test=0.771) total time=   1.2s
# [CV 1/5] END C=100, gamma=0.0001, kernel=rbf;, score=(train=0.061, test=-0.607) total time=   1.2s
# [CV 2/5] END C=100, gamma=0.0001, kernel=rbf;, score=(train=0.103, test=0.061) total time=   1.2s
# [CV 3/5] END C=100, gamma=0.0001, kernel=rbf;, score=(train=0.087, test=-0.001) total time=   1.3s
# [CV 4/5] END C=100, gamma=0.0001, kernel=rbf;, score=(train=0.116, test=0.073) total time=   1.2s
# [CV 5/5] END C=100, gamma=0.0001, kernel=rbf;, score=(train=0.114, test=-0.108) total time=   1.9s
# [CV 1/5] END C=1000, gamma=0.1, kernel=rbf;, score=(train=0.914, test=0.858) total time=   1.8s
# [CV 2/5] END C=1000, gamma=0.1, kernel=rbf;, score=(train=0.935, test=0.909) total time=   1.3s
# [CV 3/5] END C=1000, gamma=0.1, kernel=rbf;, score=(train=0.936, test=0.890) total time=   1.3s
# [CV 4/5] END C=1000, gamma=0.1, kernel=rbf;, score=(train=0.933, test=0.890) total time=   1.2s
# [CV 5/5] END C=1000, gamma=0.1, kernel=rbf;, score=(train=0.930, test=0.888) total time=   1.1s
# [CV 1/5] END C=1000, gamma=0.01, kernel=rbf;, score=(train=0.906, test=0.901) total time=   1.1s
# [CV 2/5] END C=1000, gamma=0.01, kernel=rbf;, score=(train=0.932, test=0.909) total time=   1.2s
# [CV 3/5] END C=1000, gamma=0.01, kernel=rbf;, score=(train=0.933, test=0.882) total time=   1.2s
# [CV 4/5] END C=1000, gamma=0.01, kernel=rbf;, score=(train=0.930, test=0.885) total time=   1.1s
# [CV 5/5] END C=1000, gamma=0.01, kernel=rbf;, score=(train=0.927, test=0.882) total time=   1.1s
# [CV 1/5] END C=1000, gamma=0.001, kernel=rbf;, score=(train=0.882, test=0.917) total time=   1.1s
# [CV 2/5] END C=1000, gamma=0.001, kernel=rbf;, score=(train=0.921, test=0.894) total time=   1.1s
# [CV 3/5] END C=1000, gamma=0.001, kernel=rbf;, score=(train=0.923, test=0.859) total time=   1.2s
# [CV 4/5] END C=1000, gamma=0.001, kernel=rbf;, score=(train=0.920, test=0.855) total time=   1.3s
# [CV 5/5] END C=1000, gamma=0.001, kernel=rbf;, score=(train=0.916, test=0.861) total time=   1.1s
# [CV 1/5] END C=1000, gamma=0.0001, kernel=rbf;, score=(train=0.685, test=0.555) total time=   1.2s
# [CV 2/5] END C=1000, gamma=0.0001, kernel=rbf;, score=(train=0.795, test=0.762) total time=   1.2s
# [CV 3/5] END C=1000, gamma=0.0001, kernel=rbf;, score=(train=0.800, test=0.705) total time=   1.2s
# [CV 4/5] END C=1000, gamma=0.0001, kernel=rbf;, score=(train=0.808, test=0.776) total time=   1.2s
# [CV 5/5] END C=1000, gamma=0.0001, kernel=rbf;, score=(train=0.799, test=0.775) total time=   1.2s
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [1, 10, 100, 1000],
#                          'gamma': [0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              return_train_score=True, verbose=3)

# %%
# print best parameter after tuning
print(wind_grid.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(wind_grid.best_estimator_)
# Out:
# {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# SVR(C=1000, gamma=0.01)

# %% [markdown]
# ## Running predictions on the best model decided and Plotting them side by side

# %%
train_wind_pred = wind_grid.predict(X_wind_train)
test_wind_pred = wind_grid.predict(X_wind_test)

df = thesis_dataset[['DE_wind_generation_actual']]

train_df = train[['DE_wind_generation_actual']]
train_df.loc[:, 'DE_wind_generation_actual'] = train_wind_pred

test_df = test[['DE_wind_generation_actual']]
test_df.loc[:, 'DE_wind_generation_actual'] = test_wind_pred

# Plot all predictions
inversetransform, =plt.plot(df, label = 'Actual')
trainpredx, =plt.plot(train_df, color='orange', label = 'Train')
testpredx, =plt.plot(test_df, color='green', label = 'Test')
plt.xlabel('Date')
plt.ylabel('wind Output')
plt.legend(loc="upper right")
plt.title("Predicted vs. Actual wind Generation")
plt.show()

# %% [markdown]
# ## Regression Metrics for Wind Data

# %%
metrics('svm+rbf', test[['DE_wind_generation_actual']], test_wind_pred)

# %%
print (metrics)
# Out:
# <function metrics at 0x0000013B7F7CB600>
